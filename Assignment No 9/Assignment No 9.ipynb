# %% [markdown]
# 1. Install Required Libraries

# %%
# !pip install pandas scikit-learn nltk indic-nlp-library
# Out:
# Requirement already satisfied: pandas in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: nltk in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: click in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.5)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-3.1.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Collecting sphinx>=5.1.0 (from sphinx-argparse->indic-nlp-library)
#   Downloading sphinx-9.1.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting docutils>=0.19 (from sphinx-argparse->indic-nlp-library)
#   Downloading docutils-0.22.4-py3-none-any.whl.metadata (15 kB)
# Collecting sphinxcontrib-applehelp>=1.0.7 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp>=1.0.6 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.6 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath>=1.0.1 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-qthelp>=1.0.6 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.9 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: Jinja2>=3.1 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.4)
# Requirement already satisfied: Pygments>=2.17 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.18.0)
# Collecting snowballstemmer>=2.2 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading snowballstemmer-3.0.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: babel>=2.13 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.16.0)
# Collecting alabaster>=0.7.14 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading alabaster-1.0.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting imagesize>=1.3 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests>=2.30.0 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.3)
# Collecting roman-numerals>=1.0.0 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading roman_numerals-4.1.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=23.0 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (24.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samik\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2024.8.30)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Downloading docutils-0.22.4-py3-none-any.whl (633 kB)
#    ---------------------------------------- 0.0/633.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/633.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/633.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/633.2 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/633.2 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/633.2 kB ? eta -:--:--
#    ------------------------------- ------ 524.3/633.2 kB 479.2 kB/s eta 0:00:01
#    ---------------------------------------- 633.2/633.2 kB 516.1 kB/s  0:00:01
# Downloading sphinx-9.1.0-py3-none-any.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.9 MB 882.6 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.5/3.9 MB 882.6 kB/s eta 0:00:04
#    -------- ------------------------------- 0.8/3.9 MB 780.2 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/3.9 MB 868.0 kB/s eta 0:00:04
#    ---------- ----------------------------- 1.0/3.9 MB 868.0 kB/s eta 0:00:04
#    ------------- -------------------------- 1.3/3.9 MB 828.3 kB/s eta 0:00:04
#    ---------------- ----------------------- 1.6/3.9 MB 864.6 kB/s eta 0:00:03
#    ------------------ --------------------- 1.8/3.9 MB 923.6 kB/s eta 0:00:03
#    --------------------- ------------------ 2.1/3.9 MB 954.7 kB/s eta 0:00:02
#    ------------------------ --------------- 2.4/3.9 MB 986.9 kB/s eta 0:00:02
#    ----------------------------- ---------- 2.9/3.9 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/3.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/3.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/3.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/3.9 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 3.7/3.9 MB 932.1 kB/s eta 0:00:01
#    ------------------------------------- -- 3.7/3.9 MB 932.1 kB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 911.3 kB/s  0:00:04
# Downloading alabaster-1.0.0-py3-none-any.whl (13 kB)
# Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Downloading roman_numerals-4.1.0-py3-none-any.whl (7.7 kB)
# Downloading snowballstemmer-3.0.1-py3-none-any.whl (103 kB)
# Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl (119 kB)
# Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl (82 kB)
# Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl (98 kB)
# Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl (88 kB)
# Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl (92 kB)
# Downloading sphinx_rtd_theme-3.1.0-py2.py3-none-any.whl (7.7 MB)
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.7 MB 1.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/7.7 MB 1.8 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/7.7 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/7.7 MB 2.1 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/7.7 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.1/7.7 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 3.7/7.7 MB 2.2 MB/s eta 0:00:02
#    --------------------- ------------------ 4.2/7.7 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 5.0/7.7 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 5.2/7.7 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 5.8/7.7 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.7 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.7 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.7 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.7/7.7 MB 2.1 MB/s  0:00:03
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
# Installing collected packages: morfessor, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, roman-numerals, imagesize, docutils, alabaster, sphinx, sphinxcontrib-jquery, sphinx-argparse, sphinx-rtd-theme, indic-nlp-library
#
#    ----------------------------------------  0/17 [morfessor]
#    ----------------------------------------  0/17 [morfessor]
#    ----------------------------------------  0/17 [morfessor]
#    ----------------------------------------  0/17 [morfessor]
#    ----------------------------------------  0/17 [morfessor]
#    ----------------------------------------  0/17 [morfessor]
#    ----------------------------------------  0/17 [morfessor]
#    ----------------------------------------  0/17 [morfessor]
#    ----------------------------------------  0/17 [morfessor]
#    ----------------------------------------  0/17 [morfessor]
#    -- -----------------------------------  1/17 [sphinxcontrib-serializinghtml]
#    -- -----------------------------------  1/17 [sphinxcontrib-serializinghtml]
#    -- -----------------------------------  1/17 [sphinxcontrib-serializinghtml]
#    -- -----------------------------------  1/17 [sphinxcontrib-serializinghtml]
#    -- -----------------------------------  1/17 [sphinxcontrib-serializinghtml]
#    -- -----------------------------------  1/17 [sphinxcontrib-serializinghtml]
#    -- -----------------------------------  1/17 [sphinxcontrib-serializinghtml]
#    -- -----------------------------------  1/17 [sphinxcontrib-serializinghtml]
#    -- -----------------------------------  1/17 [sphinxcontrib-serializinghtml]
#    ---- -----------------------------------  2/17 [sphinxcontrib-qthelp]
#    ---- -----------------------------------  2/17 [sphinxcontrib-qthelp]
#    ---- -----------------------------------  2/17 [sphinxcontrib-qthelp]
#    ---- -----------------------------------  2/17 [sphinxcontrib-qthelp]
#    ------- --------------------------------  3/17 [sphinxcontrib-jsmath]
#    --------- ------------------------------  4/17 [sphinxcontrib-htmlhelp]
#    --------- ------------------------------  4/17 [sphinxcontrib-htmlhelp]
#    --------- ------------------------------  4/17 [sphinxcontrib-htmlhelp]
#    --------- ------------------------------  4/17 [sphinxcontrib-htmlhelp]
#    --------- ------------------------------  4/17 [sphinxcontrib-htmlhelp]
#    --------- ------------------------------  4/17 [sphinxcontrib-htmlhelp]
#    --------- ------------------------------  4/17 [sphinxcontrib-htmlhelp]
#    --------- ------------------------------  4/17 [sphinxcontrib-htmlhelp]
#    ----------- ----------------------------  5/17 [sphinxcontrib-devhelp]
#    ----------- ----------------------------  5/17 [sphinxcontrib-devhelp]
#    ----------- ----------------------------  5/17 [sphinxcontrib-devhelp]
#    ----------- ----------------------------  5/17 [sphinxcontrib-devhelp]
#    ----------- ----------------------------  5/17 [sphinxcontrib-devhelp]
#    -------------- -------------------------  6/17 [sphinxcontrib-applehelp]
#    -------------- -------------------------  6/17 [sphinxcontrib-applehelp]
#    -------------- -------------------------  6/17 [sphinxcontrib-applehelp]
#    -------------- -------------------------  6/17 [sphinxcontrib-applehelp]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    ---------------- -----------------------  7/17 [snowballstemmer]
#    --------------------- ------------------  9/17 [imagesize]
#    --------------------- ------------------  9/17 [imagesize]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ----------------------- ---------------- 10/17 [docutils]
#    ------------------------- -------------- 11/17 [alabaster]
#    ------------------------- -------------- 11/17 [alabaster]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    ---------------------------- ----------- 12/17 [sphinx]
#    -------------------------------- ------- 14/17 [sphinx-argparse]
#    -------------------------------- ------- 14/17 [sphinx-argparse]
#    -------------------------------- ------- 14/17 [sphinx-argparse]
#    ----------------------------------- ---- 15/17 [sphinx-rtd-theme]
#    ----------------------------------- ---- 15/17 [sphinx-rtd-theme]
#    ----------------------------------- ---- 15/17 [sphinx-rtd-theme]
#    ----------------------------------- ---- 15/17 [sphinx-rtd-theme]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ------------------------------------- -- 16/17 [indic-nlp-library]
#    ---------------------------------------- 17/17 [indic-nlp-library]
#
# Successfully installed alabaster-1.0.0 docutils-0.22.4 imagesize-1.4.1 indic-nlp-library-0.92 morfessor-2.0.6 roman-numerals-4.1.0 snowballstemmer-3.0.1 sphinx-9.1.0 sphinx-argparse-0.5.2 sphinx-rtd-theme-3.1.0 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0

# %% [markdown]
# 2. Import Libraries

# %%
import pandas as pd
import nltk
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# 3. Create Sample Hindi Dataset

# %%
data = {
    "text": [
        "यह फिल्म बहुत अच्छी है",
        "मुझे यह गाना पसंद आया",
        "यह खाना बेकार है",
        "मुझे यह मोबाइल बिल्कुल पसंद नहीं है",
        "सेवा बहुत शानदार थी",
        "यह अनुभव बहुत खराब था"
    ],
    "label": ["positive", "positive", "negative", "negative", "positive", "negative"]
}

df = pd.DataFrame(data)
df
# Out:
#                                   text     label
# 0               यह फिल्म बहुत अच्छी है  positive
# 1                मुझे यह गाना पसंद आया  positive
# 2                     यह खाना बेकार है  negative
# 3  मुझे यह मोबाइल बिल्कुल पसंद नहीं है  negative
# 4                  सेवा बहुत शानदार थी  positive
# 5                यह अनुभव बहुत खराब था  negative

# %% [markdown]
# 4. Text Preprocessing (Cleaning Hindi Text)

# %%
def clean_text(text):
    text = re.sub(r'[^\u0900-\u097F\s]', '', text)  # keep Hindi characters only
    text = text.lower()
    return text

df['cleaned_text'] = df['text'].apply(clean_text)
df
# Out:
#                                   text     label  \
# 0               यह फिल्म बहुत अच्छी है  positive
# 1                मुझे यह गाना पसंद आया  positive
# 2                     यह खाना बेकार है  negative
# 3  मुझे यह मोबाइल बिल्कुल पसंद नहीं है  negative
# 4                  सेवा बहुत शानदार थी  positive
# 5                यह अनुभव बहुत खराब था  negative
#
#                           cleaned_text
# 0               यह फिल्म बहुत अच्छी है
# 1                मुझे यह गाना पसंद आया
# 2                     यह खाना बेकार है
# 3  मुझे यह मोबाइल बिल्कुल पसंद नहीं है
# 4                  सेवा बहुत शानदार थी
# 5                यह अनुभव बहुत खराब था

# %% [markdown]
# 5. Convert Text to TF-IDF Features

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['cleaned_text'])
y = df['label']

# %% [markdown]
# 6. Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# 7. Apply Multinomial Naive Bayes

# %%
model = MultinomialNB()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %% [markdown]
# 8. Evaluate Model

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00       0.0
#     positive       0.00      0.00      0.00       2.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
# c:\Users\samik\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\samik\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\samik\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\samik\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\samik\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\samik\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# 9. Test on New Hindi Sentence

# %%
new_sentence = ["यह फिल्म शानदार और बहुत अच्छी है"]
new_clean = [clean_text(new_sentence[0])]
new_vector = vectorizer.transform(new_clean)

prediction = model.predict(new_vector)
print("Sentence:", new_sentence[0])
print("Predicted Sentiment:", prediction[0])
# Out:
# Sentence: यह फिल्म शानदार और बहुत अच्छी है
# Predicted Sentiment: negative
